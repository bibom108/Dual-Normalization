# %% [markdown]
# #### Plot the results

# %% [markdown]
# #### Abdomen dataset

# %%
text_data = """
[mri] Dice: 28.41, HD: 11.48, AHD: 4.181, lr:0.1, opti:Adam, episodic:False, path:./results_abdomen/unet_dn_ct_all_lr0.004/model/final_model.pth
[mri] Dice: 30.75, HD: 10.48, AHD: 3.947, lr:0.01, opti:Adam, episodic:False, path:./results_abdomen/unet_dn_ct_all_lr0.004/model/final_model.pth
[mri] Dice: 24.77, HD: 12.49, AHD: 5.453, lr:0.001, opti:Adam, episodic:False, path:./results_abdomen/unet_dn_ct_all_lr0.004/model/final_model.pth
[mri] Dice: 23.92, HD: 13.52, AHD: 5.923, lr:0.0001, opti:Adam, episodic:False, path:./results_abdomen/unet_dn_ct_all_lr0.004/model/final_model.pth
[mri] Dice: 23.84, HD: 13.62, AHD: 5.975, lr:1e-05, opti:Adam, episodic:False, path:./results_abdomen/unet_dn_ct_all_lr0.004/model/final_model.pth
[mri] Dice: 25.35, HD: 13.08, AHD: 5.615, lr:0.1, opti:SGD, episodic:False, path:./results_abdomen/unet_dn_ct_all_lr0.004/model/final_model.pth
[mri] Dice: 24.05, HD: 13.48, AHD: 5.924, lr:0.01, opti:SGD, episodic:False, path:./results_abdomen/unet_dn_ct_all_lr0.004/model/final_model.pth
[mri] Dice: 23.86, HD: 13.61, AHD: 5.974, lr:0.001, opti:SGD, episodic:False, path:./results_abdomen/unet_dn_ct_all_lr0.004/model/final_model.pth
[mri] Dice: 23.83, HD: 13.62, AHD: 5.979, lr:0.0001, opti:SGD, episodic:False, path:./results_abdomen/unet_dn_ct_all_lr0.004/model/final_model.pth
[mri] Dice: 23.83, HD: 13.62, AHD: 5.98, lr:1e-05, opti:SGD, episodic:False, path:./results_abdomen/unet_dn_ct_all_lr0.004/model/final_model.pth 
[ct] Dice: 2.174, HD: 55.07, AHD: 20.82, lr:0.1, opti:Adam, episodic:False, path:./results_abdomen/unet_dn_mri_all_lr0.004/model/final_model.pth
[ct] Dice: 5.062, HD: 54.17, AHD: 22.32, lr:0.01, opti:Adam, episodic:False, path:./results_abdomen/unet_dn_mri_all_lr0.004/model/final_model.pth
[ct] Dice: 16.09, HD: 23.13, AHD: 7.882, lr:0.001, opti:Adam, episodic:False, path:./results_abdomen/unet_dn_mri_all_lr0.004/model/final_model.pth
[ct] Dice: 15.05, HD: 22.11, AHD: 7.865, lr:0.0001, opti:Adam, episodic:False, path:./results_abdomen/unet_dn_mri_all_lr0.004/model/final_model.pth
[ct] Dice: 14.81, HD: 22.3, AHD: 7.964, lr:1e-05, opti:Adam, episodic:False, path:./results_abdomen/unet_dn_mri_all_lr0.004/model/final_model.pth 
[ct] Dice: 8.152, HD: 50.96, AHD: 19.08, lr:0.1, opti:SGD, episodic:False, path:./results_abdomen/unet_dn_mri_all_lr0.004/model/final_model.pth
[ct] Dice: 14.7, HD: 22.98, AHD: 8.122, lr:0.01, opti:SGD, episodic:False, path:./results_abdomen/unet_dn_mri_all_lr0.004/model/final_model.pth
[ct] Dice: 14.81, HD: 22.29, AHD: 7.958, lr:0.001, opti:SGD, episodic:False, path:./results_abdomen/unet_dn_mri_all_lr0.004/model/final_model.pth
[ct] Dice: 14.79, HD: 22.32, AHD: 7.974, lr:0.0001, opti:SGD, episodic:False, path:./results_abdomen/unet_dn_mri_all_lr0.004/model/final_model.pth
[ct] Dice: 14.78, HD: 22.33, AHD: 7.976, lr:1e-05, opti:SGD, episodic:False, path:./results_abdomen/unet_dn_mri_all_lr0.004/model/final_model.pth
"""

# %%
import pandas as pd
import re

# Initialize an empty list to store each row as a dictionary
data = []

# Regular expression pattern to capture each element in the text data
pattern = r"\[(\w+)\] Dice: (\d+\.\d+), HD: (\d+\.\d+), AHD: (\d+\.\d+), lr:(\d*\.?\d+), opti:(\w+), episodic:(\w+), path:(.+)"

# Iterate through each match in the text data
for match in re.finditer(pattern, text_data):
    domain, dice, hd, ahd, lr, opti, episodic, path = match.groups()
    data.append({
        "domain": domain,
        "dice": float(dice),
        "hd": float(hd),
        "ahd": float(ahd),
        "lr": float(lr),
        "opti": opti,
        "episodic": episodic == 'True',  # Convert to Boolean
        "path": path
    })

# Create the DataFrame
df = pd.DataFrame(data)
df
# Out:
#    domain    dice     hd     ahd      lr  opti  episodic  \
# 0     mri  28.410  11.48   4.181  0.1000  Adam     False
# 1     mri  30.750  10.48   3.947  0.0100  Adam     False
# 2     mri  24.770  12.49   5.453  0.0010  Adam     False
# 3     mri  23.920  13.52   5.923  0.0001  Adam     False
# 4     mri  25.350  13.08   5.615  0.1000   SGD     False
# 5     mri  24.050  13.48   5.924  0.0100   SGD     False
# 6     mri  23.860  13.61   5.974  0.0010   SGD     False
# 7     mri  23.830  13.62   5.979  0.0001   SGD     False
# 8      ct   2.174  55.07  20.820  0.1000  Adam     False
# 9      ct   5.062  54.17  22.320  0.0100  Adam     False
# 10     ct  16.090  23.13   7.882  0.0010  Adam     False
# 11     ct  15.050  22.11   7.865  0.0001  Adam     False
# 12     ct   8.152  50.96  19.080  0.1000   SGD     False
# 13     ct  14.700  22.98   8.122  0.0100   SGD     False
# 14     ct  14.810  22.29   7.958  0.0010   SGD     False
# ...

# %%
import matplotlib.pyplot as plt

# Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Unique domains and optimizers
domains = df['domain'].unique()
optimizers = df['opti'].unique()

# Dice Plot
for domain in domains:
    for opti in optimizers:
        subset = df[(df['domain'] == domain) & (df['opti'] == opti)]
        ax1.plot(subset['lr'], subset['dice'], marker='o', label=f"{domain}-{opti}")
ax1.set_xscale('log')
ax1.set_xlabel('Learning Rate (lr)')
ax1.set_ylabel('Dice Value')
ax1.set_title('Dice Value vs Learning Rate')
ax1.legend()

# HD Plot
for domain in domains:
    for opti in optimizers:
        subset = df[(df['domain'] == domain) & (df['opti'] == opti)]
        ax2.plot(subset['lr'], subset['hd'], marker='o', label=f"{domain}-{opti}")
ax2.set_xscale('log')
ax2.set_xlabel('Learning Rate (lr)')
ax2.set_ylabel('HD Value')
ax2.set_title('HD Value vs Learning Rate')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Cardiac Dataset

# %%
cardiac_text_data = """
[mri] Dice: 1.636, HD: 83.55, AHD: 74.74, lr:0.1, opti:Adam, episodic:False, path:./results/unet_dn_ct_all_lr0.04_e50/model/epoch_9.pth
[mri] Dice: 13.89, HD: 17.9, AHD: 5.467, lr:0.01, opti:Adam, episodic:False, path:./results/unet_dn_ct_all_lr0.04_e50/model/epoch_9.pth
[mri] Dice: 28.79, HD: 23.25, AHD: 7.215, lr:0.001, opti:Adam, episodic:False, path:./results/unet_dn_ct_all_lr0.04_e50/model/epoch_9.pth
[mri] Dice: 29.05, HD: 25.21, AHD: 7.653, lr:0.0001, opti:Adam, episodic:False, path:./results/unet_dn_ct_all_lr0.04_e50/model/epoch_9.pth
[mri] Dice: 29.06, HD: 25.4, AHD: 7.698, lr:1e-05, opti:Adam, episodic:False, path:./results/unet_dn_ct_all_lr0.04_e50/model/epoch_9.pth
[mri] Dice: 29.17, HD: 20.86, AHD: 6.618, lr:0.1, opti:SGD, episodic:False, path:./results/unet_dn_ct_all_lr0.04_e50/model/epoch_9.pth
[mri] Dice: 29.12, HD: 24.85, AHD: 7.56, lr:0.01, opti:SGD, episodic:False, path:./results/unet_dn_ct_all_lr0.04_e50/model/epoch_9.pth
[mri] Dice: 29.07, HD: 25.37, AHD: 7.689, lr:0.001, opti:SGD, episodic:False, path:./results/unet_dn_ct_all_lr0.04_e50/model/epoch_9.pth
[mri] Dice: 29.06, HD: 25.42, AHD: 7.702, lr:0.0001, opti:SGD, episodic:False, path:./results/unet_dn_ct_all_lr0.04_e50/model/epoch_9.pth
[mri] Dice: 29.06, HD: 25.43, AHD: 7.703, lr:1e-05, opti:SGD, episodic:False, path:./results/unet_dn_ct_all_lr0.04_e50/model/epoch_9.pth
[ct] Dice: 29.55, HD: 22.2, AHD: 6.394, lr:0.1, opti:Adam, episodic:False, path:./results/unet_dn_mri_all_lr0.004_e100/model/epoch_9.pth
[ct] Dice: 37.84, HD: 15.16, AHD: 4.125, lr:0.01, opti:Adam, episodic:False, path:./results/unet_dn_mri_all_lr0.004_e100/model/epoch_9.pth
[ct] Dice: 44.18, HD: 9.504, AHD: 1.436, lr:0.001, opti:Adam, episodic:False, path:./results/unet_dn_mri_all_lr0.004_e100/model/epoch_9.pth
[ct] Dice: 39.65, HD: 10.9, AHD: 1.498, lr:0.0001, opti:Adam, episodic:False, path:./results/unet_dn_mri_all_lr0.004_e100/model/epoch_9.pth
[ct] Dice: 39.04, HD: 11.05, AHD: 1.519, lr:1e-05, opti:Adam, episodic:False, path:./results/unet_dn_mri_all_lr0.004_e100/model/epoch_9.pth
[ct] Dice: 44.2, HD: 10.15, AHD: 1.213, lr:0.1, opti:SGD, episodic:False, path:./results/unet_dn_mri_all_lr0.004_e100/model/epoch_9.pth
[ct] Dice: 40.31, HD: 10.93, AHD: 1.421, lr:0.01, opti:SGD, episodic:False, path:./results/unet_dn_mri_all_lr0.004_e100/model/epoch_9.pth
[ct] Dice: 39.14, HD: 11.04, AHD: 1.507, lr:0.001, opti:SGD, episodic:False, path:./results/unet_dn_mri_all_lr0.004_e100/model/epoch_9.pth
[ct] Dice: 38.99, HD: 11.05, AHD: 1.52, lr:0.0001, opti:SGD, episodic:False, path:./results/unet_dn_mri_all_lr0.004_e100/model/epoch_9.pth
[ct] Dice: 38.98, HD: 11.06, AHD: 1.521, lr:1e-05, opti:SGD, episodic:False, path:./results/unet_dn_mri_all_lr0.004_e100/model/epoch_9.pth
"""

# %%
import pandas as pd
import re

# Initialize an empty list to store each row as a dictionary
data = []

# Regular expression pattern to capture each element in the text data
pattern = r"\[(\w+)\] Dice: (\d+\.\d+), HD: (\d+\.\d+), AHD: (\d+\.\d+), lr:(\d*\.?\d+), opti:(\w+), episodic:(\w+), path:(.+)"

# Iterate through each match in the text data
for match in re.finditer(pattern, cardiac_text_data):
    domain, dice, hd, ahd, lr, opti, episodic, path = match.groups()
    data.append({
        "domain": domain,
        "dice": float(dice),
        "hd": float(hd),
        "ahd": float(ahd),
        "lr": float(lr),
        "opti": opti,
        "episodic": episodic == 'True',  # Convert to Boolean
        "path": path
    })

# Create the DataFrame
cardiac_df = pd.DataFrame(data)
cardiac_df
# Out:
#    domain    dice      hd     ahd      lr  opti  episodic  \
# 0     mri   1.636  83.550  74.740  0.1000  Adam     False
# 1     mri  13.890  17.900   5.467  0.0100  Adam     False
# 2     mri  28.790  23.250   7.215  0.0010  Adam     False
# 3     mri  29.050  25.210   7.653  0.0001  Adam     False
# 4     mri  29.170  20.860   6.618  0.1000   SGD     False
# 5     mri  29.120  24.850   7.560  0.0100   SGD     False
# 6     mri  29.070  25.370   7.689  0.0010   SGD     False
# 7     mri  29.060  25.420   7.702  0.0001   SGD     False
# 8      ct  29.550  22.200   6.394  0.1000  Adam     False
# 9      ct  37.840  15.160   4.125  0.0100  Adam     False
# 10     ct  44.180   9.504   1.436  0.0010  Adam     False
# 11     ct  39.650  10.900   1.498  0.0001  Adam     False
# 12     ct  44.200  10.150   1.213  0.1000   SGD     False
# 13     ct  40.310  10.930   1.421  0.0100   SGD     False
# 14     ct  39.140  11.040   1.507  0.0010   SGD     False
# ...

# %%
import matplotlib.pyplot as plt

# Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
df = cardiac_df

# Unique domains and optimizers
domains = df['domain'].unique()
optimizers = df['opti'].unique()

# Dice Plot
for domain in domains:
    for opti in optimizers:
        subset = df[(df['domain'] == domain) & (df['opti'] == opti)]
        ax1.plot(subset['lr'], subset['dice'], marker='o', label=f"{domain}-{opti}")
ax1.set_xscale('log')
ax1.set_xlabel('Learning Rate (lr)')
ax1.set_ylabel('Dice Value')
ax1.set_title('Dice Value vs Learning Rate')
ax1.legend()

# HD Plot
for domain in domains:
    for opti in optimizers:
        subset = df[(df['domain'] == domain) & (df['opti'] == opti)]
        ax2.plot(subset['lr'], subset['hd'], marker='o', label=f"{domain}-{opti}")
ax2.set_xscale('log')
ax2.set_xlabel('Learning Rate (lr)')
ax2.set_ylabel('HD Value')
ax2.set_title('HD Value vs Learning Rate')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Show example

# %%
import torch
from model.unetdsbn import Unet2D
from datasets.dataset import Dataset, ToTensor, CreateOnehotLabel
import torchvision.transforms as tfs
from torch.utils.data import DataLoader

# Define parameters
model_path = './results_abdomen/unet_dn_mri_all_non1_lr0.004/model/final_model.pth'  # Path to model weights
data_dir = './data_abdomen/npz_all_non1'
test_domain_list = ['mri']  # Update this with your domain name

# Initialize the model and load weights
model = Unet2D(num_classes=5, num_domains=2, norm='dsbn')
model.load_state_dict(torch.load(model_path))
model = model.cuda().eval()

# Load a test dataset
dataset = Dataset(
    base_dir=data_dir,
    split='test',
    domain_list=test_domain_list,
    transforms=tfs.Compose([
        CreateOnehotLabel(num_classes=5, dataset='abdomen_mri'),
        ToTensor()
    ])
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)  # Load one sample at a time
# Out:
# /tmp/ipykernel_20742/4118784583.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))

# %%
pred_y = output.cpu().detach().numpy()
plt.imshow(pred_y[0][0])

# %%
plt.imshow(mask[0])

# %%
list(abd_mri_label_values.values())
# Out:
# [0, 63, 126, 189, 252]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors

threshold = 0.0 # ignore as background if max prediction of other class is less than threshold
abd_mri_label_values = {0: 0, 1: 63, 2: 126, 3: 189, 4: 252}
colors = [
    'black', 'red', 'blue', 'green', 'purple'
]
label_values = list(abd_mri_label_values.values())
cmap = mcolors.ListedColormap(colors)
bounds = label_values + [max(label_values) + 1]  # Add an upper bound for normalization
norm = mcolors.BoundaryNorm(bounds, cmap.N)

# def plot_prediction(model, dataloader):
with torch.no_grad():
    for idx, (batch, id) in enumerate(dataloader):
        sample_data = batch['image'].cuda()
        onehot_mask = batch['onehot_label'].detach().numpy()
        mask = batch['label'].detach().numpy()
        dis = 99999999
        best_out = None
        for domain_id in range(2):
            # model.load_state_dict(torch.load(os.path.join(model_dir, 'epoch_9.pth')))
            output = model(sample_data, domain_label=domain_id*torch.ones(sample_data.shape[0], dtype=torch.long))
            # means, vars = get_bn_statis(model, domain_id)
            # new_dis = cal_distance(means, means_list[domain_id], vars, vars_list[domain_id])
            # if new_dis < dis:
            #     best_out = output
            #     dis = new_dis

        # output = best_out
        pred_y = output.cpu().detach().numpy()
        # pred_y = np.argmax(pred_y, axis=1)

        pred_y_excluding_first_class = pred_y[:, 1:, :, :]
        pred_classes = np.argmax(pred_y_excluding_first_class, axis=1) + 1  # +1 to adjust class indices
        pred_probs = np.max(pred_y_excluding_first_class, axis=1)  
        pred_classes[pred_probs < threshold] = 0 

        # pred_classes = np.argmax(pred_y, axis=1)

        # Plot the results
        fig, axes = plt.subplots(1, 2, figsize=(10, 5))
        
        # Ground truth
        axes[0].imshow(mask[0], cmap=cmap, norm=norm, alpha=0.5)
        axes[0].imshow(sample_data[0][0].cpu().detach().numpy(), cmap='gray', origin='lower', alpha=0.7)
        axes[0].set_title("Ground Truth Mask")
        axes[0].axis('off')

        # Prediction
        mapped_pred_classes = np.vectorize(abd_mri_label_values.get)(pred_classes[0])
        axes[1].imshow(mapped_pred_classes, cmap=cmap, norm=norm, alpha=0.5)
        axes[1].imshow(sample_data[0][0].cpu().detach().numpy(), cmap='gray', origin='lower', alpha=0.7)
        axes[1].set_title("Predicted Mask")
        axes[1].axis('off')

        plt.show()
        break  # Exit after displaying one sample

# Example usage
# plot_prediction(model, dataloader)

# %%
pred_y = output.cpu().detach().numpy()
pred_y_excluding_first_class = pred_y[:, 1:, :, :]

# Apply argmax on the modified array
pred_classes = np.argmax(pred_y_excluding_first_class, axis=1) + 1  # +1 to adjust class indices

np.unique(pred_classes[0])
# Out:
# array([2, 3])

# %%
mapped_pred_classes
# Out:
# array([[  0,   0,   0, ..., 189,   0,   0],
#        [  0, 189, 189, ..., 189, 189,   0],
#        [  0, 189, 189, ..., 189, 189, 189],
#        ...,
#        [  0, 189, 189, ..., 189, 189, 189],
#        [  0, 189, 189, ..., 189, 189, 189],
#        [  0,   0,   0, ..., 189,   0,   0]])

# %%
np.unique(pred_classes[0])
# Out:
# array([0, 3])

# %%
pred_y_excluding_first_class.max()
# Out:
# 0.99770665

# %%
pred_y = output.cpu().detach().numpy()
np.sum(pred_y[0][0] < 0.5)
# Out:
# 0

# %%
import numpy as np

# Sample prediction with random probabilities
pred_y = np.array([[[[0.1, 0.3, 0.2, 0.4],
                     [0.5, 0.1, 0.2, 0.2],
                     [0.2, 0.7, 0.6, 0.1],
                     [0.3, 0.2, 0.1, 0.4]],

                    [[0.5, 0.2, 0.6, 0.3],
                     [0.2, 0.7, 0.1, 0.4],
                     [0.5, 0.1, 0.2, 0.3],
                     [0.4, 0.2, 0.6, 0.1]],

                    [[0.4, 0.5, 0.2, 0.3],
                     [0.3, 0.2, 0.7, 0.4],
                     [0.3, 0.2, 0.2, 0.6],
                     [0.3, 0.6, 0.3, 0.5]]],

                   [[[0.1, 0.3, 0.2, 0.4],
                     [0.5, 0.1, 0.2, 0.2],
                     [0.2, 0.7, 0.6, 0.1],
                     [0.3, 0.2, 0.1, 0.4]],

                    [[0.5, 0.2, 0.6, 0.3],
                     [0.2, 0.7, 0.1, 0.4],
                     [0.5, 0.1, 0.2, 0.3],
                     [0.4, 0.2, 0.6, 0.1]],

                    [[0.4, 0.5, 0.2, 0.3],
                     [0.3, 0.2, 0.7, 0.4],
                     [0.3, 0.2, 0.2, 0.6],
                     [0.3, 0.6, 0.3, 0.5]]]])

# Get the predicted classes
pred_classes = np.argmax(pred_y, axis=1)
print(pred_classes.shape)
# Out:
# (2, 4, 4)

# %%
import numpy as np

# Predicted probabilities for each class (shape: [batch_size, num_classes, height, width])
pred_y = np.random.rand(1, 3, 3, 3)  # Example random prediction for 5 classes

# Define a threshold value for ignoring class 0
threshold = 0.8  # You can change this threshold as needed

# Get the probabilities for each class
pred_classes = np.argmax(pred_y[:, 1:, :, :], axis=1)  # Predicted class labels (shape: [batch_size, height, width])

# Step 2: Get the maximum probability for each pixel (shape: [batch_size, height, width])
pred_probs = np.max(pred_y[:, 1:, :, :], axis=1)  # Maximum probability (shape: [batch_size, height, width])

# Step 3: Apply the threshold: If max probability < threshold, set to background (class 0)
pred_classes[pred_probs < threshold] = 0 

print('pred_y',pred_y)
print('pred_probs', pred_probs)
print('pred_classes', pred_classes)
# Out:
# pred_y [[[[0.75680933 0.06281021 0.61496179]
#    [0.80670597 0.01045674 0.67683932]
#    [0.93307768 0.15274357 0.64981123]]
#
#   [[0.66821631 0.35220453 0.12317831]
#    [0.10055303 0.38943221 0.79967057]
#    [0.89242371 0.94039037 0.54097899]]
#
#   [[0.61863176 0.47003534 0.720787  ]
#    [0.84143304 0.45845225 0.84683003]
#    [0.68643354 0.97338326 0.59915407]]]]
# pred_probs [[[0.66821631 0.47003534 0.720787  ]
#   [0.84143304 0.45845225 0.84683003]
#   [0.89242371 0.97338326 0.59915407]]]
# pred_classes [[[0 0 0]
#   [1 0 1]
#   [0 1 0]]]

# %% [markdown]
# # Visualization

# %%
import os
import argparse
import numpy as np
import medpy.metric.binary as mmb

from tqdm import tqdm
from PIL import Image
from model.unetdsbn import Unet2D
from utils.palette import color_map
from datasets.dataset import Dataset, ToTensor, CreateOnehotLabel

import torch
import torchvision.transforms as tfs
from torch.nn import DataParallel
from torch.nn import PairwiseDistance
from torch.utils.data import DataLoader
import logging


parser = argparse.ArgumentParser()
parser.add_argument('--data_dir', type=str, default='./data/brats/npz_data')
parser.add_argument('--n_classes', type=int, default=2)
parser.add_argument('--test_domain_list', nargs='+', type=str)
parser.add_argument('--model_dir', type=str,  default='./results/unet_dn/model', help='model_dir')
parser.add_argument('--batch_size', type=int,  default=1)
parser.add_argument('--save_label', dest='save_label', action='store_true')
parser.add_argument('--label_dir', type=str,  default='./results/unet_dn', help='model_dir')
parser.add_argument('--gpu_ids', type=str,  default='0', help='GPU to use')
FLAGS = parser.parse_args()

def get_bn_statis(model, domain_id):
    means = []
    vars = []
    for name, param in model.state_dict().items():
        if 'bns.{}.running_mean'.format(domain_id) in name:
            means.append(param.clone())
        elif 'bns.{}.running_var'.format(domain_id) in name:
            vars.append(param.clone())
    return means, vars

def cal_distance(means_1, means_2, vars_1, vars_2):
    pdist = PairwiseDistance(p=2)
    dis = 0
    for (mean_1, mean_2, var_1, var_2) in zip(means_1, means_2, vars_1, vars_2):
        dis += (pdist(mean_1.reshape(1, mean_1.shape[0]), mean_2.reshape(1, mean_2.shape[0])) + pdist(var_1.reshape(1, var_1.shape[0]), var_2.reshape(1, var_2.shape[0])))
    return dis.item()

if __name__ == '__main__':
    logging.basicConfig(level=logging.DEBUG, 
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
                    handlers=[
                        logging.FileHandler("result.log"),
                        logging.StreamHandler()
                    ])
    os.environ['CUDA_VISIBLE_DEVICES'] = FLAGS.gpu_ids
    model_dir = FLAGS.model_dir
    n_classes = FLAGS.n_classes
    test_domain_list = FLAGS.test_domain_list
    num_domain = len(test_domain_list)
    print('Start Testing.')

    cmap = color_map(n_color=256, normalized=False).reshape(-1)
    
    if not os.path.exists(FLAGS.label_dir):
        os.mkdir(FLAGS.label_dir)
    
    for test_idx in range(num_domain):
        model = Unet2D(num_classes=n_classes, num_domains=2, norm='dsbn')
        model.load_state_dict(torch.load(os.path.join(model_dir, 'final_model.pth')))
        model = DataParallel(model).cuda()
        means_list = []
        vars_list = []
        for i in range(2):
            means, vars = get_bn_statis(model, i)
            means_list.append(means)
            vars_list.append(vars)

        model.train()
        dataset = Dataset(base_dir=FLAGS.data_dir, split='test', domain_list=test_domain_list[test_idx],
                        transforms=tfs.Compose([
                            CreateOnehotLabel(num_classes=FLAGS.n_classes),
                            ToTensor()
                        ]))
        dataloader = DataLoader(dataset, batch_size=FLAGS.batch_size, shuffle=False, num_workers=8, pin_memory=True)
        tbar = tqdm(dataloader, ncols=150)
        total_dice = 0
        total_hd = 0
        total_asd = 0
        dice_list = []
        hd_list = []
        asd_list = []
        with torch.no_grad():
            for idx, (batch, id) in enumerate(tbar):
                sample_data = batch['image'].cuda()
                onehot_mask = batch['onehot_label'].detach().numpy()
                mask = batch['label'].detach().numpy()
                dis = 99999999
                best_out = None
                for domain_id in range(2):
                    # model.load_state_dict(torch.load(os.path.join(model_dir, 'epoch_9.pth')))
                    output = model(sample_data, domain_label=domain_id*torch.ones(sample_data.shape[0], dtype=torch.long))
                    means, vars = get_bn_statis(model, domain_id)
                    new_dis = cal_distance(means, means_list[domain_id], vars, vars_list[domain_id])
                    if new_dis < dis:
                        best_out = output
                        dis = new_dis

                output = best_out
                pred_y = output.cpu().detach().numpy()
                pred_y = np.argmax(pred_y, axis=1)

                if pred_y.sum() == 0 or mask.sum() == 0:
                    total_dice += 0
                    total_hd += 100
                    total_asd += 100
                else:
                    total_dice += mmb.dc(pred_y, mask)
                    total_hd += mmb.hd95(pred_y, mask)
                    total_asd += mmb.asd(pred_y, mask)
                
                if FLAGS.save_label:
                    if not os.path.exists(os.path.join(FLAGS.label_dir, test_domain_list[test_idx])):
                        os.mkdir(os.path.join(FLAGS.label_dir, test_domain_list[test_idx]))
                    for i, pred_mask in enumerate(pred_y):
                        pred_mask = Image.fromarray(np.uint8(pred_mask.T))
                        pred_mask = pred_mask.convert('P')
                        pred_mask.putpalette(cmap)
                        pred_mask.save(os.path.join(FLAGS.label_dir, test_domain_list[test_idx], id[i] + '.png'))
        
        logging.info('Domain: {}, Dice: {}, HD: {}, ASD: {}'.format(
            test_domain_list[test_idx],
            round(100 * total_dice / (idx + 1), 2),
            round(total_hd / (idx + 1), 2),
            round(total_asd / (idx + 1), 2)
        ))
